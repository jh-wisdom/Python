# %% [markdown]
# #### 수행평가 영역 별 평가 반영 요소

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 포트폴리오

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 정보문화

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 문제 해결 프로그래밍

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 프로젝트 기록 예시 양식
#
# * 아래 부분을 더블 클릭하고 수정하면 됨
# * 형식은 자유롭게 수정 가능
# * ####을 붙이면 항목별로 분리 작성 가능
# * 편집 후 키보드 ESC 키 누르면 나올 수 있음.
# * (+) 코드는 프로그래밍 코드를 (+) 텍스트는 설명 부분을 추가할 수 있음 (상황 따라 맘대로)
# * (+) 텍스트로 만든 부분을 더블 클릭 후 화면을 캡처한 후 Ctrl + V를 누른 후 ESC를 누르면 그림파일 삽입 가능
# * **작성하다가 실수로 칸을 삭제했을 때는 수정 -> 셀 삭제 실행취소 누르면 됨**
# * **그래도 복구 안되거나 아예 처음부터 시작하고 싶을 때에는 클래스룸 상에서 포트폴리오 X 눌러 삭제하고 다시 사본 만들기**
# * **수업 중 수행평가 준비할 시간 부여할 예정**

# %% [markdown]
# #### 프로젝트 인정 조건
#
# 0. 인터넷에 있는 소스 코드를 **그대로 복사 붙여넣기 하여 제출했을 시 제출로 인정하지 않음. (알고리즘은 그대로인데 변수 이름만 수정, 함수 요소만 수정 등도 인정하지 않음)**, 또 본인이 작성한 코드에 대해서 **설명을 요구했을 시 제대로 설명하지 못했을 시**도 제출로 인정하지 않음.
#
# 1. 수업 시간에 했던 내용을 **그대로 제출했을 경우** 제출로 인정하지 않음.
# 2. 3차원 공간에 **단순 도형을 나열만 했을 경우** 제출로 인정하지 않음.
# 3. 단 본인이 만들고 싶은 모양이나 움직임을 상세하게 서술하고 이를 구현했을 시는 제출로 인정함.(**단순 구현 시 모양과 움직임(애니메이션 또는 키보드 조작)을 모두 구현할 것**)
# 4. 본인이 생각하고 고민한 내용이 아닌 단순한 물체의 나열, 단순한 물체의 움직임 등은 제출로 인정하지 않음. (예 : 물체 3개 만들고 키보드로 삼각형 움직이기, 무한하게 등속 운동하는 공의 모습 )
# 5. 가장 좋은 방법은 **프로젝트 주제를 선생님과 상의하는 방법**
# 6. 팀으로 수행 시 **팀원 구성(최대 2인)을 비공개 댓글로 선생님에게 전달할 것**.

# %% [markdown]
# #### 추천 프로젝트
#
# 1. 본인이 규칙을 인지하고 만들어 낸 3차원 조형물 (여러 개의 도형을 규칙 및 제어문(조건문, 반복문)을 활용하여 예술적으로 만들어내기)
# 2. 과학 시간에 학습한 내용을 3차원 공간에 구현하여 학습한 내용대로 결론이 보이는지 검증하기
# 3. 여러 물체를 만들고 물체 간의 상호작용 하는 세계 구현하기 (2번과 연계하여 자동차와 조형물을 만들고 충돌 시 충돌량을 표시하는 프로젝트 등)
# 4. 키보드 조작이 들어간 간단한 게임 만들기
# 5. 키보드 조작이 아니더라도 만들 수 있는 간단한 게임 (여러 개의 카드를 생성하고 동일한 카드를 키보드 또는 마우스로 골라 짝을 찾는 짝맞추기 게임, 점수와 시간 부여)
# 6. 현실 공간을 3차원 시뮬레이터에 구현해보기(교실, 내방, 우리 학교 등)
# 7. 이외 무한~~~

# %% [markdown]
# #### 해결하고자 하는 문제
#
# 1.   Vpython 구와 텍스처를 이용하여
# 2.   지구와 달 태양의 움직임을 과학 시간에 학습한 내용을 통해 구현한다.
# 3.   지구, 달, 태양의 자전 및 공전 주기에 대해 더 학습하고
# 4.   정확한 자전, 공전 개념을 토대로 구현한다.
#
#
#
# #### 문제 선정이유
#
# *   지구과학 분야에 관심이 많아 지구과학적 내용을 시뮬레이션으로 구현하고 싶었다.
# *   학습한 내용을 이론으로만 이해했는데 이를 실제 구현하여 내가 배웠던 이론이 정말 잘 작동하는지 알고 싶다.
# *   나는 지구과학교사가 되고 싶기에 잘 프로그래밍하여 만들어놓으면 나중에 수업 시에 활용할 수 있을 것 같다.
# *   지구, 달, 태양의 움직임을 잘 구현한 후 이를 확장하여 우리 태양계 전체에 대한 운동을 구현해보고 싶다.
#
#
# #### 문제 분석 (문제 해결을 위해 필요한 요소 및 작업들)
#
# *   지구, 달, 태양의 크기와 공전, 자전 주기
# *   지구, 달, 태양을 구 형태로 나타내어야 한다.
# *   구 형태로 나타내고 자전과 공전의 움직임을 반영해 보아야 한다.
# *   Vpython으로 자전을 나타낼 수 있을지 알아보아야 한다.
#
# #### 해결 과정과 결과 (시행착오 및 소스코드)
#
# *   오픈 API를 활용하는 과정에서 하루에 사용할 수 있는 접근수가 제한되어 있어 어려웠다.
# *   코드를 CSV로 불러올지 판다스로 불러서 분석해야 할지 어려움이 있었다

# %%
#### 이 부분에 작성한 코드를 붙여넣을 것.
#### 작성한 코드를 붙여넣고 #<- 주석 표시를 붙여 Glowscript 링크를 붙여넣을 것.
#### 여러 개의 + 코드 칸, + 텍스트 칸을 사용해도 전혀 지장 없음.
#### 주석 (#) 붙여서 설명 쓰기을 적극 활용할 것.

# %% [markdown]
# #### 해결 후 느낀점 (1명이 수행하면 한명 만 느낀점을 쓰면 됨.)
#
# OOO :
#
# XXX :
